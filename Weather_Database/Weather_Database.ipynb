# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Import config from another folder
import sys
sys.path.append('../')
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Date": city_date})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dunedin
# Processing Record 2 of Set 1 | chokurdakh
# Processing Record 3 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | panalingaan
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | clyde river
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | dicabisagan
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | awbari
# Processing Record 18 of Set 1 | torbay
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | sinjar
# Processing Record 21 of Set 1 | college
# Processing Record 22 of Set 1 | chichicapam
# City not found. Skipping...
# Processing Record 23 of Set 1 | roebourne
# Processing Record 24 of Set 1 | karaman
# Processing Record 25 of Set 1 | sur
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | krumbach
# Processing Record 28 of Set 1 | san jose
# Processing Record 29 of Set 1 | rocha
# Processing Record 30 of Set 1 | broken hill
# Processing Record 31 of Set 1 | katsuura
# Processing Record 32 of Set 1 | gao
# Processing Record 33 of Set 1 | victoria
# Processing Record 34 of Set 1 | carnarvon
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | bayan
# Processing Record 37 of Set 1 | presidencia roque saenz pena
# Processing Record 38 of Set 1 | tiksi
# Processing Record 39 of Set 1 | talas
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | san pedro
# Processing Record 42 of Set 1 | nouadhibou
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | newport
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | vila do maio
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | talnakh
# Processing Record 2 of Set 2 | isangel
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | unguia
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | kavieng
# Processing Record 7 of Set 2 | bandraboua
# Processing Record 8 of Set 2 | kruisfontein
# Processing Record 9 of Set 2 | puerto leguizamo
# Processing Record 10 of Set 2 | rikitea
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | ballina
# Processing Record 13 of Set 2 | itupiranga
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | shizunai
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | nome
# Processing Record 18 of Set 2 | alice springs
# Processing Record 19 of Set 2 | bonavista
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 2 | sept-iles
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | tanete
# Processing Record 26 of Set 2 | yerbogachen
# Processing Record 27 of Set 2 | hit
# Processing Record 28 of Set 2 | senftenberg
# Processing Record 29 of Set 2 | bubaque
# Processing Record 30 of Set 2 | ribeira grande
# Processing Record 31 of Set 2 | mataura
# Processing Record 32 of Set 2 | aklavik
# Processing Record 33 of Set 2 | baley
# Processing Record 34 of Set 2 | severo-kurilsk
# Processing Record 35 of Set 2 | lapeer
# Processing Record 36 of Set 2 | macau
# Processing Record 37 of Set 2 | brae
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | esperance
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | khorixas
# Processing Record 45 of Set 2 | lasa
# Processing Record 46 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 2 | lompoc
# Processing Record 48 of Set 2 | cape town
# Processing Record 49 of Set 2 | qaqortoq
# Processing Record 50 of Set 2 | port alfred
# Processing Record 1 of Set 3 | klin
# Processing Record 2 of Set 3 | saint-pierre
# Processing Record 3 of Set 3 | gamba
# Processing Record 4 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 3 | morondava
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | bara
# Processing Record 8 of Set 3 | colac
# Processing Record 9 of Set 3 | paamiut
# Processing Record 10 of Set 3 | qena
# Processing Record 11 of Set 3 | sao miguel do araguaia
# Processing Record 12 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | te anau
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | fairbanks
# Processing Record 17 of Set 3 | san quintin
# Processing Record 18 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 3 | kenitra
# Processing Record 20 of Set 3 | vila velha
# Processing Record 21 of Set 3 | constitucion
# Processing Record 22 of Set 3 | haines junction
# Processing Record 23 of Set 3 | mehkar
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | havre-saint-pierre
# Processing Record 26 of Set 3 | vardo
# Processing Record 27 of Set 3 | deogarh
# Processing Record 28 of Set 3 | tatarsk
# Processing Record 29 of Set 3 | vila franca do campo
# Processing Record 30 of Set 3 | brawley
# Processing Record 31 of Set 3 | tuktoyaktuk
# Processing Record 32 of Set 3 | leningradskiy
# Processing Record 33 of Set 3 | sola
# Processing Record 34 of Set 3 | zhangye
# Processing Record 35 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 3 | balassagyarmat
# Processing Record 37 of Set 3 | bambous virieux
# Processing Record 38 of Set 3 | atka
# City not found. Skipping...
# Processing Record 39 of Set 3 | austin
# Processing Record 40 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 3 | lexington
# Processing Record 42 of Set 3 | bull savanna
# Processing Record 43 of Set 3 | harer
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | coruripe
# Processing Record 46 of Set 3 | rudnogorsk
# Processing Record 47 of Set 3 | port macquarie
# Processing Record 48 of Set 3 | porto novo
# Processing Record 49 of Set 3 | beyneu
# Processing Record 50 of Set 3 | khatanga
# Processing Record 1 of Set 4 | deputatskiy
# Processing Record 2 of Set 4 | codrington
# Processing Record 3 of Set 4 | enshi
# Processing Record 4 of Set 4 | norman wells
# Processing Record 5 of Set 4 | castro
# Processing Record 6 of Set 4 | roald
# Processing Record 7 of Set 4 | mugan
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | imeni babushkina
# Processing Record 10 of Set 4 | sitka
# Processing Record 11 of Set 4 | camacha
# Processing Record 12 of Set 4 | anton lizardo
# Processing Record 13 of Set 4 | pousat
# City not found. Skipping...
# Processing Record 14 of Set 4 | corinto
# Processing Record 15 of Set 4 | iberia
# Processing Record 16 of Set 4 | narsaq
# Processing Record 17 of Set 4 | east london
# Processing Record 18 of Set 4 | itarema
# Processing Record 19 of Set 4 | nassau
# Processing Record 20 of Set 4 | lata
# Processing Record 21 of Set 4 | port shepstone
# Processing Record 22 of Set 4 | hulin
# Processing Record 23 of Set 4 | kodiak
# Processing Record 24 of Set 4 | shahr-e babak
# Processing Record 25 of Set 4 | prince albert
# Processing Record 26 of Set 4 | flinders
# Processing Record 27 of Set 4 | tecoanapa
# Processing Record 28 of Set 4 | russell
# Processing Record 29 of Set 4 | astoria
# Processing Record 30 of Set 4 | avarua
# Processing Record 31 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 4 | severo-yeniseyskiy
# Processing Record 33 of Set 4 | chute-aux-outardes
# Processing Record 34 of Set 4 | puerto baquerizo moreno
# Processing Record 35 of Set 4 | pevek
# Processing Record 36 of Set 4 | kamenka
# Processing Record 37 of Set 4 | port-gentil
# Processing Record 38 of Set 4 | yulara
# Processing Record 39 of Set 4 | sobolevo
# Processing Record 40 of Set 4 | hobart
# Processing Record 41 of Set 4 | hammerfest
# Processing Record 42 of Set 4 | hays
# Processing Record 43 of Set 4 | noumea
# Processing Record 44 of Set 4 | inhambane
# Processing Record 45 of Set 4 | alofi
# Processing Record 46 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 4 | ksenyevka
# City not found. Skipping...
# Processing Record 48 of Set 4 | loknya
# Processing Record 49 of Set 4 | saint george
# Processing Record 50 of Set 4 | blagoveshchenka
# Processing Record 1 of Set 5 | marv dasht
# City not found. Skipping...
# Processing Record 2 of Set 5 | ilulissat
# Processing Record 3 of Set 5 | mehamn
# Processing Record 4 of Set 5 | manokwari
# Processing Record 5 of Set 5 | tukrah
# Processing Record 6 of Set 5 | saqqez
# Processing Record 7 of Set 5 | cidreira
# Processing Record 8 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 5 | san fernando
# Processing Record 10 of Set 5 | pisco
# Processing Record 11 of Set 5 | nabire
# Processing Record 12 of Set 5 | murgab
# Processing Record 13 of Set 5 | whitefish
# Processing Record 14 of Set 5 | touros
# Processing Record 15 of Set 5 | hargeysa
# Processing Record 16 of Set 5 | maumere
# Processing Record 17 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 5 | maracaibo
# Processing Record 19 of Set 5 | poya
# Processing Record 20 of Set 5 | ewa beach
# Processing Record 21 of Set 5 | adrar
# Processing Record 22 of Set 5 | makakilo city
# Processing Record 23 of Set 5 | toamasina
# Processing Record 24 of Set 5 | kem
# Processing Record 25 of Set 5 | geraldton
# Processing Record 26 of Set 5 | catabangan
# Processing Record 27 of Set 5 | progreso
# Processing Record 28 of Set 5 | batemans bay
# Processing Record 29 of Set 5 | panaba
# Processing Record 30 of Set 5 | labuhan
# Processing Record 31 of Set 5 | arkhangelsk
# Processing Record 32 of Set 5 | andenes
# Processing Record 33 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 5 | huaihua
# Processing Record 35 of Set 5 | puerto quijarro
# Processing Record 36 of Set 5 | tierralta
# Processing Record 37 of Set 5 | bathsheba
# Processing Record 38 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 39 of Set 5 | merritt island
# Processing Record 40 of Set 5 | tarusan
# Processing Record 41 of Set 5 | oistins
# Processing Record 42 of Set 5 | grand forks
# Processing Record 43 of Set 5 | bengkulu
# Processing Record 44 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 5 | longyearbyen
# Processing Record 46 of Set 5 | skovorodino
# Processing Record 47 of Set 5 | boleslawiec
# Processing Record 48 of Set 5 | richards bay
# Processing Record 49 of Set 5 | provideniya
# Processing Record 50 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 6 | agadez
# Processing Record 2 of Set 6 | klaksvik
# Processing Record 3 of Set 6 | tonstad
# Processing Record 4 of Set 6 | batagay-alyta
# Processing Record 5 of Set 6 | coxim
# Processing Record 6 of Set 6 | purranque
# Processing Record 7 of Set 6 | merauke
# Processing Record 8 of Set 6 | port hedland
# Processing Record 9 of Set 6 | amboasary
# Processing Record 10 of Set 6 | georgetown
# Processing Record 11 of Set 6 | belmonte
# Processing Record 12 of Set 6 | sunland park
# Processing Record 13 of Set 6 | broome
# Processing Record 14 of Set 6 | manicore
# Processing Record 15 of Set 6 | malavalli
# Processing Record 16 of Set 6 | padang
# Processing Record 17 of Set 6 | plettenberg bay
# Processing Record 18 of Set 6 | saint anthony
# Processing Record 19 of Set 6 | souillac
# Processing Record 20 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 22 of Set 6 | vostok
# Processing Record 23 of Set 6 | port hardy
# Processing Record 24 of Set 6 | grindavik
# Processing Record 25 of Set 6 | moose factory
# Processing Record 26 of Set 6 | suntar
# Processing Record 27 of Set 6 | husavik
# Processing Record 28 of Set 6 | saldanha
# Processing Record 29 of Set 6 | tadine
# Processing Record 30 of Set 6 | lagoa
# Processing Record 31 of Set 6 | salalah
# Processing Record 32 of Set 6 | suzu
# City not found. Skipping...
# Processing Record 33 of Set 6 | jiangkou
# Processing Record 34 of Set 6 | puerto colombia
# Processing Record 35 of Set 6 | coquimbo
# Processing Record 36 of Set 6 | kashan
# Processing Record 37 of Set 6 | dixon
# Processing Record 38 of Set 6 | honningsvag
# Processing Record 39 of Set 6 | milkovo
# Processing Record 40 of Set 6 | baruun-urt
# Processing Record 41 of Set 6 | lerwick
# Processing Record 42 of Set 6 | angoche
# Processing Record 43 of Set 6 | ayagoz
# Processing Record 44 of Set 6 | lensk
# Processing Record 45 of Set 6 | srednekolymsk
# Processing Record 46 of Set 6 | alamosa
# Processing Record 47 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 48 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 6 | chuy
# Processing Record 50 of Set 6 | tahoua
# Processing Record 1 of Set 7 | harper
# Processing Record 2 of Set 7 | yoichi
# Processing Record 3 of Set 7 | praia
# Processing Record 4 of Set 7 | sao paulo de olivenca
# Processing Record 5 of Set 7 | hay river
# Processing Record 6 of Set 7 | axim
# Processing Record 7 of Set 7 | sakaiminato
# Processing Record 8 of Set 7 | azare
# Processing Record 9 of Set 7 | miri
# Processing Record 10 of Set 7 | iquitos
# Processing Record 11 of Set 7 | ardahan
# Processing Record 12 of Set 7 | madera
# Processing Record 13 of Set 7 | arona
# Processing Record 14 of Set 7 | timra
# Processing Record 15 of Set 7 | laguna
# Processing Record 16 of Set 7 | kavaratti
# Processing Record 17 of Set 7 | san patricio
# Processing Record 18 of Set 7 | ketchikan
# Processing Record 19 of Set 7 | shebalino
# Processing Record 20 of Set 7 | reconquista
# Processing Record 21 of Set 7 | mosquera
# Processing Record 22 of Set 7 | banjar
# Processing Record 23 of Set 7 | lavrentiya
# Processing Record 24 of Set 7 | abalak
# Processing Record 25 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 7 | mitsamiouli
# Processing Record 27 of Set 7 | peterhead
# Processing Record 28 of Set 7 | timizart
# Processing Record 29 of Set 7 | kahului
# Processing Record 30 of Set 7 | rio gallegos
# Processing Record 31 of Set 7 | tshane
# Processing Record 32 of Set 7 | ulladulla
# Processing Record 33 of Set 7 | egvekinot
# Processing Record 34 of Set 7 | neuquen
# Processing Record 35 of Set 7 | pucallpa
# Processing Record 36 of Set 7 | ostrovnoy
# Processing Record 37 of Set 7 | kleck
# City not found. Skipping...
# Processing Record 38 of Set 7 | peace river
# Processing Record 39 of Set 7 | roshchino
# Processing Record 40 of Set 7 | gorontalo
# Processing Record 41 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 7 | pacific grove
# Processing Record 43 of Set 7 | coffs harbour
# Processing Record 44 of Set 7 | alexandria
# Processing Record 45 of Set 7 | san felipe
# Processing Record 46 of Set 7 | olafsvik
# Processing Record 47 of Set 7 | jinchang
# Processing Record 48 of Set 7 | rawson
# Processing Record 49 of Set 7 | bundaberg
# Processing Record 50 of Set 7 | taltal
# Processing Record 1 of Set 8 | ahipara
# Processing Record 2 of Set 8 | kieta
# Processing Record 3 of Set 8 | furano
# Processing Record 4 of Set 8 | tiarei
# Processing Record 5 of Set 8 | catacamas
# Processing Record 6 of Set 8 | khandyga
# Processing Record 7 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 8 | kaitangata
# Processing Record 9 of Set 8 | shingu
# Processing Record 10 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 8 | toora-khem
# Processing Record 12 of Set 8 | baherden
# Processing Record 13 of Set 8 | rio grande
# Processing Record 14 of Set 8 | aswan
# Processing Record 15 of Set 8 | santa cruz de la palma
# Processing Record 16 of Set 8 | polson
# Processing Record 17 of Set 8 | andros town
# Processing Record 18 of Set 8 | orlik
# Processing Record 19 of Set 8 | mao
# Processing Record 20 of Set 8 | los tangos
# Processing Record 21 of Set 8 | vao
# Processing Record 22 of Set 8 | bilibino
# Processing Record 23 of Set 8 | semey
# Processing Record 24 of Set 8 | buraydah
# Processing Record 25 of Set 8 | yarmouth
# Processing Record 26 of Set 8 | caravelas
# Processing Record 27 of Set 8 | zvenigovo
# Processing Record 28 of Set 8 | faanui
# Processing Record 29 of Set 8 | talavera
# Processing Record 30 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 8 | noshiro
# Processing Record 32 of Set 8 | palaikastron
# Processing Record 33 of Set 8 | kadoma
# Processing Record 34 of Set 8 | guasdualito
# Processing Record 35 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 8 | bereda
# Processing Record 37 of Set 8 | maceio
# Processing Record 38 of Set 8 | malaya serdoba
# Processing Record 39 of Set 8 | panguna
# Processing Record 40 of Set 8 | magadan
# Processing Record 41 of Set 8 | yuksekova
# Processing Record 42 of Set 8 | sao filipe
# Processing Record 43 of Set 8 | paciran
# Processing Record 44 of Set 8 | ixtapa
# Processing Record 45 of Set 8 | caruray
# Processing Record 46 of Set 8 | fountain
# Processing Record 47 of Set 8 | ancud
# Processing Record 48 of Set 8 | kralendijk
# Processing Record 49 of Set 8 | tinde
# Processing Record 50 of Set 8 | atar
# Processing Record 1 of Set 9 | ibia
# Processing Record 2 of Set 9 | nokaneng
# Processing Record 3 of Set 9 | kargasok
# Processing Record 4 of Set 9 | burns lake
# Processing Record 5 of Set 9 | aitape
# Processing Record 6 of Set 9 | umba
# Processing Record 7 of Set 9 | shitanjing
# Processing Record 8 of Set 9 | eirunepe
# Processing Record 9 of Set 9 | kattivakkam
# Processing Record 10 of Set 9 | poum
# Processing Record 11 of Set 9 | ahvaz
# Processing Record 12 of Set 9 | nhulunbuy
# Processing Record 13 of Set 9 | san cristobal
# Processing Record 14 of Set 9 | zhigansk
# Processing Record 15 of Set 9 | sabang
# Processing Record 16 of Set 9 | santa maria
# Processing Record 17 of Set 9 | dourbali
# Processing Record 18 of Set 9 | kununurra
# Processing Record 19 of Set 9 | cherskiy
# Processing Record 20 of Set 9 | ruangwa
# Processing Record 21 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 9 | hirara
# Processing Record 23 of Set 9 | salta
# Processing Record 24 of Set 9 | sweetwater
# Processing Record 25 of Set 9 | akyab
# Processing Record 26 of Set 9 | fare
# Processing Record 27 of Set 9 | usinsk
# Processing Record 28 of Set 9 | muros
# Processing Record 29 of Set 9 | marawi
# Processing Record 30 of Set 9 | wasilla
# Processing Record 31 of Set 9 | alcudia
# Processing Record 32 of Set 9 | cururupu
# Processing Record 33 of Set 9 | biak
# Processing Record 34 of Set 9 | korla
# Processing Record 35 of Set 9 | esmeraldas
# Processing Record 36 of Set 9 | saint-georges
# Processing Record 37 of Set 9 | visnes
# Processing Record 38 of Set 9 | cockburn town
# Processing Record 39 of Set 9 | tilichiki
# Processing Record 40 of Set 9 | grand-lahou
# Processing Record 41 of Set 9 | urumqi
# Processing Record 42 of Set 9 | honiara
# Processing Record 43 of Set 9 | owando
# Processing Record 44 of Set 9 | baykit
# Processing Record 45 of Set 9 | saint-francois
# Processing Record 46 of Set 9 | belaya gora
# Processing Record 47 of Set 9 | dubbo
# Processing Record 48 of Set 9 | kainantu
# Processing Record 49 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 50 of Set 9 | najran
# Processing Record 1 of Set 10 | buala
# Processing Record 2 of Set 10 | effingham
# Processing Record 3 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 10 | kollo
# Processing Record 5 of Set 10 | aksu
# Processing Record 6 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 7 of Set 10 | kapoeta
# Processing Record 8 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 9 of Set 10 | goderich
# Processing Record 10 of Set 10 | granville
# Processing Record 11 of Set 10 | shelburne
# Processing Record 12 of Set 10 | laem sing
# Processing Record 13 of Set 10 | onega
# Processing Record 14 of Set 10 | danielskuil
# Processing Record 15 of Set 10 | maues
# Processing Record 16 of Set 10 | killybegs
# Processing Record 17 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 18 of Set 10 | helena
# Processing Record 19 of Set 10 | ihosy
# Processing Record 20 of Set 10 | nanortalik
# Processing Record 21 of Set 10 | shimoda
# Processing Record 22 of Set 10 | totolapan
# Processing Record 23 of Set 10 | boyolangu
# Processing Record 24 of Set 10 | port neches
# Processing Record 25 of Set 10 | dawlatabad
# Processing Record 26 of Set 10 | lorengau
# Processing Record 27 of Set 10 | chapais
# Processing Record 28 of Set 10 | prince rupert
# Processing Record 29 of Set 10 | macusani
# Processing Record 30 of Set 10 | port moresby
# Processing Record 31 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 32 of Set 10 | hovd
# Processing Record 33 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 10 | olot
# Processing Record 35 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 10 | male
# Processing Record 37 of Set 10 | oussouye
# Processing Record 38 of Set 10 | mizdah
# Processing Record 39 of Set 10 | fomboni
# Processing Record 40 of Set 10 | ramnagar
# Processing Record 41 of Set 10 | acarau
# Processing Record 42 of Set 10 | brownsville
# Processing Record 43 of Set 10 | berezovyy
# Processing Record 44 of Set 10 | nam tha
# City not found. Skipping...
# Processing Record 45 of Set 10 | ponta delgada
# Processing Record 46 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 10 | kandrian
# Processing Record 48 of Set 10 | cerritos
# Processing Record 49 of Set 10 | bay roberts
# Processing Record 50 of Set 10 | edenderry
# Processing Record 1 of Set 11 | pangnirtung
# Processing Record 2 of Set 11 | mackenzie
# Processing Record 3 of Set 11 | zonguldak
# Processing Record 4 of Set 11 | phan thiet
# Processing Record 5 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 11 | arlit
# Processing Record 7 of Set 11 | tatarskaya pishlya
# Processing Record 8 of Set 11 | dejen
# Processing Record 9 of Set 11 | auki
# Processing Record 10 of Set 11 | shirokiy
# Processing Record 11 of Set 11 | stokmarknes
# Processing Record 12 of Set 11 | portland
# Processing Record 13 of Set 11 | namibe
# Processing Record 14 of Set 11 | amahai
# Processing Record 15 of Set 11 | koutiala
# Processing Record 16 of Set 11 | tifton
# Processing Record 17 of Set 11 | bonthe
# Processing Record 18 of Set 11 | sidmouth
# Processing Record 19 of Set 11 | gisborne
# Processing Record 20 of Set 11 | skegness
# Processing Record 21 of Set 11 | korem
# Processing Record 22 of Set 11 | asau
# Processing Record 23 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 11 | hasaki
# Processing Record 25 of Set 11 | avera
# Processing Record 26 of Set 11 | komsomolskiy
# Processing Record 27 of Set 11 | malanje
# Processing Record 28 of Set 11 | hambantota
# Processing Record 29 of Set 11 | saint-joseph
# Processing Record 30 of Set 11 | verkhoyansk
# Processing Record 31 of Set 11 | trairi
# Processing Record 32 of Set 11 | bandarbeyla
# Processing Record 33 of Set 11 | margate
# Processing Record 34 of Set 11 | puerto maldonado
# Processing Record 35 of Set 11 | nanzhang
# Processing Record 36 of Set 11 | coihaique
# Processing Record 37 of Set 11 | half moon bay
# Processing Record 38 of Set 11 | turmero
# Processing Record 39 of Set 11 | sisimiut
# Processing Record 40 of Set 11 | moerai
# Processing Record 41 of Set 11 | puerto escondido
# Processing Record 42 of Set 11 | daru
# Processing Record 43 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 44 of Set 11 | tutoia
# Processing Record 45 of Set 11 | cayenne
# Processing Record 46 of Set 11 | manaus
# Processing Record 47 of Set 11 | truro
# Processing Record 48 of Set 11 | murmashi
# Processing Record 49 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 50 of Set 11 | inirida
# Processing Record 1 of Set 12 | isetskoye
# Processing Record 2 of Set 12 | oksfjord
# Processing Record 3 of Set 12 | villefranche-sur-saone
# Processing Record 4 of Set 12 | johnstown
# Processing Record 5 of Set 12 | novoagansk
# Processing Record 6 of Set 12 | mount gambier
# Processing Record 7 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 12 | milos
# Processing Record 9 of Set 12 | parsons
# Processing Record 10 of Set 12 | gornoye loo
# Processing Record 11 of Set 12 | real
# Processing Record 12 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 12 | kashi
# Processing Record 14 of Set 12 | le vauclin
# Processing Record 15 of Set 12 | fort nelson
# Processing Record 16 of Set 12 | sioux lookout
# Processing Record 17 of Set 12 | logrono
# Processing Record 18 of Set 12 | ust-kuyga
# Processing Record 19 of Set 12 | gizo
# Processing Record 20 of Set 12 | quchan
# Processing Record 21 of Set 12 | ola
# Processing Record 22 of Set 12 | pedernales
# Processing Record 23 of Set 12 | bireun
# Processing Record 24 of Set 12 | luanda
# Processing Record 25 of Set 12 | zalantun
# Processing Record 26 of Set 12 | namuac
# Processing Record 27 of Set 12 | viedma
# Processing Record 28 of Set 12 | port lincoln
# Processing Record 29 of Set 12 | dum duma
# Processing Record 30 of Set 12 | ejura
# Processing Record 31 of Set 12 | birobidzhan
# Processing Record 32 of Set 12 | igrim
# Processing Record 33 of Set 12 | yakeshi
# Processing Record 34 of Set 12 | valdepenas
# Processing Record 35 of Set 12 | puerto del rosario
# Processing Record 36 of Set 12 | kemijarvi
# Processing Record 37 of Set 12 | yar-sale
# Processing Record 38 of Set 12 | beberibe
# Processing Record 39 of Set 12 | wembley
# Processing Record 40 of Set 12 | maracacume
# Processing Record 41 of Set 12 | luderitz
# Processing Record 42 of Set 12 | santa rosa
# Processing Record 43 of Set 12 | pafos
# Processing Record 44 of Set 12 | zhanakorgan
# Processing Record 45 of Set 12 | halifax
# Processing Record 46 of Set 12 | yuci
# Processing Record 47 of Set 12 | tuatapere
# Processing Record 48 of Set 12 | opuwo
# Processing Record 49 of Set 12 | tuy hoa
# Processing Record 50 of Set 12 | cabo san lucas
# Processing Record 1 of Set 13 | popondetta
# Processing Record 2 of Set 13 | iqaluit
# Processing Record 3 of Set 13 | yumen
# Processing Record 4 of Set 13 | miamisburg
# Processing Record 5 of Set 13 | nuuk
# Processing Record 6 of Set 13 | sampit
# Processing Record 7 of Set 13 | port blair
# Processing Record 8 of Set 13 | karakol
# Processing Record 9 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 10 of Set 13 | mayo
# Processing Record 11 of Set 13 | bally
# Processing Record 12 of Set 13 | demba
# Processing Record 13 of Set 13 | bambanglipuro
# Processing Record 14 of Set 13 | prado
# Processing Record 15 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 17 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 13 | fairview
# Processing Record 19 of Set 13 | guerrero negro
# Processing Record 20 of Set 13 | vitry-le-francois
# Processing Record 21 of Set 13 | catio
# Processing Record 22 of Set 13 | talcahuano
# Processing Record 23 of Set 13 | sinazongwe
# Processing Record 24 of Set 13 | santa isabel do rio negro
# Processing Record 25 of Set 13 | zyryanka
# Processing Record 26 of Set 13 | raudeberg
# Processing Record 27 of Set 13 | lima
# Processing Record 28 of Set 13 | toftir
# City not found. Skipping...
# Processing Record 29 of Set 13 | christchurch
# Processing Record 30 of Set 13 | tezu
# Processing Record 31 of Set 13 | kochubey
# Processing Record 32 of Set 13 | sangar
# Processing Record 33 of Set 13 | bella vista
# Processing Record 34 of Set 13 | luganville
# Processing Record 35 of Set 13 | chernyshevskiy
# Processing Record 36 of Set 13 | tahe
# Processing Record 37 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 13 | cedar city
# Processing Record 39 of Set 13 | antalaha
# Processing Record 40 of Set 13 | kanganpur
# Processing Record 41 of Set 13 | cochrane
# Processing Record 42 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 43 of Set 13 | sterling
# Processing Record 44 of Set 13 | ylojarvi
# Processing Record 45 of Set 13 | haapiti
# Processing Record 46 of Set 13 | mandera
# Processing Record 47 of Set 13 | riyadh
# Processing Record 48 of Set 13 | thinadhoo
# Processing Record 49 of Set 13 | santa helena de goias
# Processing Record 50 of Set 13 | baghdad
# Processing Record 1 of Set 14 | pitimbu
# Processing Record 2 of Set 14 | kabinda
# Processing Record 3 of Set 14 | pokhara
# Processing Record 4 of Set 14 | port hawkesbury
# Processing Record 5 of Set 14 | isla vista
# Processing Record 6 of Set 14 | chicama
# Processing Record 7 of Set 14 | yablochnyy
# Processing Record 8 of Set 14 | jacareacanga
# Processing Record 9 of Set 14 | macklin
# Processing Record 10 of Set 14 | kurkino
# Processing Record 11 of Set 14 | tatawin
# Processing Record 12 of Set 14 | barra do corda
# Processing Record 13 of Set 14 | wuwei
# Processing Record 14 of Set 14 | zeya
# Processing Record 15 of Set 14 | trelew
# Processing Record 16 of Set 14 | suhbaatar
# Processing Record 17 of Set 14 | sibolga
# Processing Record 18 of Set 14 | atambua
# Processing Record 19 of Set 14 | brookings
# Processing Record 20 of Set 14 | maldonado
# Processing Record 21 of Set 14 | wufeng
# Processing Record 22 of Set 14 | havelock
# Processing Record 23 of Set 14 | tremembe
# Processing Record 24 of Set 14 | haflong
# Processing Record 25 of Set 14 | naze
# Processing Record 26 of Set 14 | salamiyah
# Processing Record 27 of Set 14 | ivanava
# Processing Record 28 of Set 14 | sulangan
# Processing Record 29 of Set 14 | san luis
# Processing Record 30 of Set 14 | stromness
# Processing Record 31 of Set 14 | marang
# Processing Record 32 of Set 14 | vredendal
# Processing Record 33 of Set 14 | yagodnoye
# Processing Record 34 of Set 14 | ismailia
# Processing Record 35 of Set 14 | aguimes
# Processing Record 36 of Set 14 | mezen
# Processing Record 37 of Set 14 | marsaxlokk
# Processing Record 38 of Set 14 | santa cruz
# Processing Record 39 of Set 14 | mweka
# Processing Record 40 of Set 14 | cap malheureux
# Processing Record 41 of Set 14 | winslow
# Processing Record 42 of Set 14 | kushiro
# Processing Record 43 of Set 14 | crestview
# Processing Record 44 of Set 14 | maniitsoq
# Processing Record 45 of Set 14 | buon me thuot
# City not found. Skipping...
# Processing Record 46 of Set 14 | ahuimanu
# Processing Record 47 of Set 14 | kungurtug
# Processing Record 48 of Set 14 | nara
# Processing Record 49 of Set 14 | ferrol
# Processing Record 50 of Set 14 | abha
# Processing Record 1 of Set 15 | hereford
# Processing Record 2 of Set 15 | razole
# Processing Record 3 of Set 15 | alghero
# Processing Record 4 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 15 | karratha
# Processing Record 6 of Set 15 | kirakira
# Processing Record 7 of Set 15 | sinnamary
# Processing Record 8 of Set 15 | kenai
# Processing Record 9 of Set 15 | san vicente
# Processing Record 10 of Set 15 | trier
# Processing Record 11 of Set 15 | ottawa
# Processing Record 12 of Set 15 | jiuquan
# Processing Record 13 of Set 15 | oranjestad
# Processing Record 14 of Set 15 | dzialdowo
# Processing Record 15 of Set 15 | port said
# Processing Record 16 of Set 15 | devonport
# Processing Record 17 of Set 15 | mananjary
# Processing Record 18 of Set 15 | oranjemund
# Processing Record 19 of Set 15 | gusau
# Processing Record 20 of Set 15 | kaabong
# Processing Record 21 of Set 15 | cardoso
# Processing Record 22 of Set 15 | savannah bight
# Processing Record 23 of Set 15 | basoko
# Processing Record 24 of Set 15 | lamesa
# Processing Record 25 of Set 15 | labytnangi
# Processing Record 26 of Set 15 | marzuq
# Processing Record 27 of Set 15 | namatanai
# Processing Record 28 of Set 15 | west plains
# Processing Record 29 of Set 15 | alakurtti
# Processing Record 30 of Set 15 | dali
# Processing Record 31 of Set 15 | chake chake
# Processing Record 32 of Set 15 | hoa binh
# Processing Record 33 of Set 15 | durango
# Processing Record 34 of Set 15 | locri
# Processing Record 35 of Set 15 | natal
# Processing Record 36 of Set 15 | taoudenni
# Processing Record 37 of Set 15 | sharjah
# Processing Record 38 of Set 15 | coos bay
# Processing Record 39 of Set 15 | kloulklubed
# Processing Record 40 of Set 15 | arvika
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 678

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Dunedin      NZ -45.8742  170.5036     59.81        89          79
# 1      Chokurdakh      RU  70.6333  147.9167      2.62        99          93
# 2    Ponta Do Sol      PT  32.6667  -17.1000     63.23        54          13
# 3  Port Elizabeth      ZA -33.9180   25.5701     70.11        83           0
# 4     Panalingaan      PH   8.7842  117.4231     77.58        86          33
# 5           Airai      TL  -8.9266  125.4092     58.78        89          99
# 6       Mahebourg      MU -20.4081   57.7000     77.29        88          40
# 7       Hithadhoo      MV  -0.6000   73.0833     83.28        70          93
# 8    Punta Arenas      CL -53.1500  -70.9167     53.62        66          75
# 9     Clyde River      CA  70.4692  -68.5914      3.43        78          75
#
#    Wind Speed Current Description                 Date
# 0        5.99       broken clouds  2022-04-20 18:42:04
# 1        4.07     overcast clouds  2022-04-20 18:42:04
# 2        7.20          few clouds  2022-04-20 18:42:05
# 3        3.44           clear sky  2022-04-20 18:41:02
# 4        3.11    scattered clouds  2022-04-20 18:42:06
# 5        2.24     overcast clouds  2022-04-20 18:42:07
# 6        3.44    scattered clouds  2022-04-20 18:42:07
# 7        3.42     overcast clouds  2022-04-20 18:42:08
# 8       18.41          light rain  2022-04-20 18:42:10
# 9       13.80       broken clouds  2022-04-20 18:42:10

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
